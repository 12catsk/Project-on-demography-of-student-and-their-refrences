# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = './cleaned_data.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#         Timestamp              Fullname  Number of student Date of BIRTH   \
# 0  7/4/2024 10:54     Nabin Thapa Magar       9.860882e+09     10/16/2069
# 1  7/4/2024 10:56  Bishwa Dhami Danuwar       9.811274e+09      1/15/2065
# 2  7/4/2024 11:00          Prabhu Karki       9.870682e+09      6/11/2063
# 3  7/4/2024 11:09           Suman Jimee       9.815319e+09     11/27/2065
# 4  7/4/2024 11:15         Angel Jayswal       9.845122e+09     11/26/2007
#
#     GPA                      School name\n    school address  \
# 0  2.67              Balu sECONDARY sCHOOL  Kalighat-2 Byasi
# 1  2.61  Shree Ram Prasad Secondary school           Sabaila
# 2  3.29                       M.M.M.R.S.S               Jiri
# 3  2.84                 Shree Sharada Mavi       Kharang -10
# 4  3.90             Shree Ma.Vi Biratnagar        Biratnagar
#
#   School principal name     Stream                 academic program   ...  \
# 0       Ambika Nyaichai  Management                       HM and TMS  ...
# ...

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Fullname', 'Number of student', 'Date of BIRTH ', 'GPA',
#        'School name\n', 'school address', 'School principal name', 'Stream ',
#        'academic program ', 'Father Name', 'Fathers profession \n',
#        'Fathers number ', 'Mothers Name', 'Mother's number',
#        'Local gurdian name', 'Local gurdian relation', 'Local gurdian number',
#        'Permanent address', ' Permanent Province  ', 'Permanent District',
#        'Permanent Municipality', 'Permanent Ward No', 'Temporary Address',
#        'Temporary Province', 'Temporary District', 'Temporary Municipality',
#        'Permanent Ward No.1', 'refrence', 'shift'],
#       dtype='object')

# %%
df.columns = [col.strip() for col in df.columns]

# %%
permanent_province_counts = df['Permanent Province'].value_counts()
plt.figure(figsize=(10, 6))
permanent_province_counts.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Permanent Province')
plt.ylabel('')
plt.show()

# %%
reference_counts = df['refrence'].value_counts()
plt.figure(figsize=(10, 6))
reference_counts.plot.bar()
plt.title('Count of References')
plt.xlabel('Reference')
plt.ylabel('Count')
plt.show()

# %%
temporary_province_counts = df['Temporary Province'].value_counts()
plt.figure(figsize=(10, 6))
permanent_province_counts.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Distribution of  Province')
plt.ylabel('')
plt.show()
